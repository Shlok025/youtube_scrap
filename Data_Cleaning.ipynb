# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('MultipleChannel.csv')
df
# Out:
#            Channel_Name                                              Title  \
# 0           Times Music  Sunke (Full Audio) | Khan Bhaini | Teji Sandhu...
# 1           Times Music  ✨ Lose yourself in the melody of love! 💖🎵 Dil ...
# 2           Times Music  🎉 Let the magic of Khali Peeli Baatein brighte...
# 3           Times Music  Peace Lily (Synth-Pop Mix) | Knockwell |  @Aar...
# 4           Times Music  Gustakhiyaan (House Mix) | Knockwell | Raghav ...
# ...                 ...                                                ...
# 42571  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42572  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42573  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42574  Sony Music India  You Are My Soniya - K3G | Kareena Kapoor | Hri...
# 42575  Sony Music India  Kuch Kuch Hota Hai- Official Video | Udit Nara...
#
#       Date_Released     Views   Likes  Comments
# ...

# %%
df['Title']
# Out:
# 0        Sunke (Full Audio) | Khan Bhaini | Teji Sandhu...
# 1        ✨ Lose yourself in the melody of love! 💖🎵 Dil ...
# 2        🎉 Let the magic of Khali Peeli Baatein brighte...
# 3        Peace Lily (Synth-Pop Mix) | Knockwell |  @Aar...
# 4        Gustakhiyaan (House Mix) | Knockwell | Raghav ...
#                                ...
# 42571    Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42572    Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42573    Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42574    You Are My Soniya - K3G | Kareena Kapoor | Hri...
# 42575    Kuch Kuch Hota Hai- Official Video | Udit Nara...
# Name: Title, Length: 42576, dtype: object

# %%
import re

# Function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # Emoticons
                               u"\U0001F300-\U0001F5FF"  # Symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # Transport & map symbols
                               u"\U0001F700-\U0001F77F"  # Alchemical symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric shapes
                               u"\U0001F800-\U0001F8FF"  # Supplemental symbols
                               u"\U0001F900-\U0001F9FF"  # Supplemental symbols and pictographs
                               u"\U0001FA00-\U0001FA6F"  # Symbols and pictographs extended-A
                               u"\U0001FA70-\U0001FAFF"  # Symbols and pictographs extended-B
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251"  # Enclosed characters
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
# Apply function to remove emojis
df['Title'] = df['Title'].apply(remove_emojis)

# %%
df
# Out:
#            Channel_Name                                              Title  \
# 0           Times Music  Sunke (Full Audio) | Khan Bhaini | Teji Sandhu...
# 1           Times Music   Lose yourself in the melody of love!  Dil Tuj...
# 2           Times Music   Let the magic of Khali Peeli Baatein brighten...
# 3           Times Music  Peace Lily (Synth-Pop Mix) | Knockwell |  @Aar...
# 4           Times Music  Gustakhiyaan (House Mix) | Knockwell | Raghav ...
# ...                 ...                                                ...
# 42571  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42572  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42573  Sony Music India  Crook - Emraan Hashmi's Brand New Supercool Pr...
# 42574  Sony Music India  You Are My Soniya - K3G | Kareena Kapoor | Hri...
# 42575  Sony Music India  Kuch Kuch Hota Hai- Official Video | Udit Nara...
#
#       Date_Released     Views   Likes  Comments
# ...

# %%
df = df.drop_duplicates(subset=['Title'], keep='first')

# %%
df.shape
# Out:
# (40999, 6)

# %%
# df.to_excel('csv/Cleaned_Music_Channel.xlsx' , index = False)  For Excel format

# %%
df.to_csv('csv/Cleaned_Music_Channel.csv' , index = False)  # For csv format
